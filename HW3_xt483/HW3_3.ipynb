# %%
import pylab as pl
import numpy as np

# %matplotlib inline

# %%
import os
! curl -O "https://github.com/fedhere/PUI2016_fb55/blob/master/Lab3_fb55/times.txt"

# %%
testsite_array = []
with open('times.txt') as my_file:
    data = my_file.read().split('\r\n')
    for line in data:
        testsite_array.append(line)
time = np.array(testsite_array)

# %%
type(time)
time
# Out:
# array([ '\n\n\n\n<!DOCTYPE html>\n<html lang="en" class="">\n  <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# object: http://ogp.me/ns/object# article: http://ogp.me/ns/article# profile: http://ogp.me/ns/profile#">\n    <meta charset=\'utf-8\'>\n    \n\n    <link crossorigin="anonymous" href="https://assets-cdn.github.com/assets/frameworks-8cd585e8453902a5ece8e3f65c2316fe11a87e6e1fc9b1138e08785b39f65427.css" media="all" rel="stylesheet" />\n    <link crossorigin="anonymous" href="https://assets-cdn.github.com/assets/github-32986c0e3d905f34959de0ab6880e1cb667dfeaa0d61a2b6c6d1c947c9c2cad7.css" media="all" rel="stylesheet" />\n    \n    \n    <link crossorigin="anonymous" href="https://assets-cdn.github.com/assets/site-f6ce114ac3bc145f575863b4a6dbdf65e924bccb184fc4d4a4f5a09819b4173d.css" media="all" rel="stylesheet" />\n    \n\n    <link as="script" href="https://assets-cdn.github.com/assets/frameworks-2c76cc192ef357ffd1604a67307c1426cfd7513a720b1a87d1f53eb24a928308.js" rel="preload" />\n    \n    <link as="script" href="https://assets-cdn.github.com/assets/github-97a9c3bab94c41cd3db8300864b8a5a0a3e414ee59082ab5707d0f1768838a26.js" rel="preload" />\n\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta http-equiv="Content-Language" content="en">\n    <meta name="viewport" content="width=device-width">\n    \n    <title>PUI2016_fb55/times.txt at master \xc2\xb7 fedhere/PUI2016_fb55 \xc2\xb7 GitHub</title>\n    <link rel="search" type="application/opensearchdescription+xml" href="/opensearch.xml" title="GitHub">\n    <link rel="fluid-icon" href="https://github.com/fluidicon.png" title="GitHub">\n    <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png">\n    <link rel="apple-touch-icon" sizes="60x60" href="/apple-touch-icon-60x60.png">\n    <link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png">\n    <link rel="apple-touch-icon" sizes="76x76" href="/apple-touch-icon-76x76.png">\n    <link rel="apple-touch-icon" sizes="114x114" href="/apple-touch-icon-114x114.png">\n    <link rel="apple-touch-icon" sizes="120x120" href="/apple-touch-icon-120x120.png">\n    <link rel="apple-touch-icon" sizes="144x144" href="/apple-touch-icon-144x144.png">\n    <link rel="apple-touch-icon" sizes="152x152" href="/apple-touch-icon-152x152.png">\n    <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon-180x180.png">\n    <meta property="fb:app_id" content="1401488693436528">\n\n      <meta content="https://avatars0.githubusercontent.com/u/1696902?v=3&amp;s=400" name="twitter:image:src" /><meta content="@github" name="twitter:site" /><meta content="summary" name="twitter:card" /><meta content="fedhere/PUI2016_fb55" name="twitter:title" /><meta content="Contribute to PUI2016_fb55 development by creating an account on GitHub." name="twitter:description" />\n      <meta content="https://avatars0.githubusercontent.com/u/1696902?v=3&amp;s=400" property="og:image" /><meta content="GitHub" property="og:site_name" /><meta content="object" property="og:type" /><meta content="fedhere/PUI2016_fb55" property="og:title" /><meta content="https://github.com/fedhere/PUI2016_fb55" property="og:url" /><meta content="Contribute to PUI2016_fb55 development by creating an account on GitHub." property="og:description" />\n      <meta name="browser-stats-url" content="https://api.github.com/_private/browser/stats">\n    <meta name="browser-errors-url" content="https://api.github.com/_private/browser/errors">\n    <link rel="assets" href="https://assets-cdn.github.com/">\n    \n    <meta name="pjax-timeout" content="1000">\n    \n    <meta name="request-id" content="807A48A6:735F:CC1BE90:57EB4288" data-pjax-transient>\n\n    <meta name="msapplication-TileImage" content="/windows-tile.png">\n    <meta name="msapplication-TileColor" content="#ffffff">\n    <meta name="selected-link" value="repo_source" data-pjax-transient>\n\ ...
#       dtype='|S51587')

# %%
with open("times.txt", 'r') as f:
      data = f.read().split('\r\n')
for line in data:
    numbers.extend([n for n in map(float, line.split()) if n > 0])        
lst = filter(None, itertools.chain(map(float, line.split()) for line in data))
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-122-cd2d5f059251> in <module>()
#       3       data = f.read().split('\r\n')
#       4 for line in data:
# ----> 5     numbers.extend([n for n in map(float, line.split()) if n > 0])
#       6 lst = filter(None, itertools.chain(map(float, line.split()) for line in data))
#
# NameError: name 'numbers' is not defined

# %%
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-115-bec7050179fe> in <module>()
# ----> 1 np.genfromtxt('times.txt', delimiter=';')
#
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/numpy/lib/npyio.pyc in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows)
#    1767             # Raise an exception ?
#    1768             if invalid_raise:
# -> 1769                 raise ValueError(errmsg)
#    1770             # Issue a warning ?
#    1771             else:
#
# ValueError: Some errors were detected !
#     Line #37 (got 2 columns instead of 1)
#     Line #38 (got 2 columns instead of 1)
#     Line #56 (got 5 columns instead of 1)
#     Line #135 (got 3 columns instead of 1)
#     Line #380 (got 2 columns instead of 1)
#     Line #397 (got 2 columns instead of 1)
#     Line #844 (got 3 columns instead of 1)
#     Line #845 (got 2 columns instead of 1)
#     Line #875 (got 2 columns instead of 1)
#     Line #912 (got 2 columns instead of 1)
